# %% [markdown]
# # Comparative Mythology
#
# Visualising the structures of comparative mythology

# %%
# globals & modules

import wikipediaParser

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# main entry point

wiki = wikipediaParser.WikipediaParser()

parent_category = '/wiki/Category:Comparative_mythology'
parent_soup = wiki.getSoup(
    parent_category
)

parsed_page = wiki.parseSoup(
    parent_soup,
    parent_category
)

with open('comparative_mythology.json', 'w') as outfile:
    json.dump(parsed_page, outfile)
# Out:
# /Users/mschultz/Documents/Misc/comparativeMythology/wikipediaParser.py:31: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 31 of the file /Users/mschultz/Documents/Misc/comparativeMythology/wikipediaParser.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   ''' Parses a subcategory entry'''
# /wiki/Category:Comparative_mythology
# 0
# Animals_in_mythology
# 1
# Animals_in_Norse_mythology
# 2
# Birds_in_mythology
# 11
# Creation_myths
# 80
# Adam_and_Eve
# 81
# Flood_myths
# 350

# %%
pd.DataFrame(parsed_page)
# Out:
#                               node                                parent  \
# 0             Animals_in_mythology  /wiki/Category:Comparative_mythology
# 1       Animals_in_Norse_mythology                  Animals_in_mythology
# 2         Birds_in_Norse_mythology            Animals_in_Norse_mythology
# 3        Horses_in_Norse_mythology            Animals_in_Norse_mythology
# 4        Wolves_in_Norse_mythology            Animals_in_Norse_mythology
# ..                             ...                                   ...
# 709        Mythological_archetypes  /wiki/Category:Comparative_mythology
# 710         Mythological_creatures  /wiki/Category:Comparative_mythology
# 711                Mythology_books  /wiki/Category:Comparative_mythology
# 712  Proto-Indo-European_mythology  /wiki/Category:Comparative_mythology
# 713                     Underworld  /wiki/Category:Comparative_mythology
#
#                                         node_href  \
# ...
